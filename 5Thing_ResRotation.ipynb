# %% [markdown]
# #Yêu cầu chủ đề.
#
# Xây dựng phần mềm nhận dạng 5 đối tượng trong phòng
# * a. Xây dựng, thu thập tập dữ liệu các đối tượng cần nhận dạng
# * b. Phân lớp các đối tượng trên
# * c. Tìm gốc quay của đối tượng
# * d. Triển khai mô hình (web, desktop)

# %% [markdown]
# # Giới thiệu.
# - Tiếp nối yêu cầu của đề tài: c. Tìm gốc quay của đối tượng
# - Từ dataset ban đầu, nhóm chúng em thực hiện xoay ảnh với 3 góc độ là 90, 180, 270 và ảnh gốc ban đầu sẽ là 0 độ.
# - Số lượng ảnh ban đầu là 5000 ảnh, sau khi xoay sẽ tăng lên là 20 000 ảnh tương ứng với mỗi góc xoay có 5000 ảnh.

# %% [markdown]
# * Mục tiêu chính của bài toán phân loại này là tìm ra mối quan hệ, mẫu hoặc đặc trưng của vật ở các góc độ khác nhau trong ảnh.

# %% [markdown]
# # 1 - Chuẩn bị dữ liệu.

# %% [markdown]
# ## 1.1 Tải và uzip Dataset.

# %%
#https://drive.google.com/file/d/11nlOAtsKG2x_52FwYLp-XcpPiGPIME7s/view?usp=sharing
# %%shell
gdown -q 11nlOAtsKG2x_52FwYLp-XcpPiGPIME7s
unzip -q Rotated_IM.zip -d /content/dataset

# %% [markdown]
# #Import libary

# %%
import os
import shutil
import random
import progressbar
import cv2
import imutils
from imutils import paths
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from joblib import dump, load
import plotly.express as px
from google.colab import drive
from keras.models import load_model

import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical, img_to_array, load_img
from keras.applications import imagenet_utils
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, BatchNormalization
from tensorflow.keras import layers, Sequential, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# # Mount Google Drive
# drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Đường dẫn đến thư mục chứa dữ liệu
path_to_data = '/content/dataset/Rotated_IM'

# Đường dẫn đến thư mục chứa dữ liệu đã được chia
path_to_train = '/content/Train'
path_to_test = '/content/Test'
path_to_valid = '/content/Valid'

# Tạo các thư mục nếu chúng không tồn tại
os.makedirs(path_to_train, exist_ok=True)
os.makedirs(path_to_test, exist_ok=True)
os.makedirs(path_to_valid, exist_ok=True)

# Tạo thư mục train/test/valid cho từng class
classes = os.listdir(path_to_data)
for class_name in classes:
    os.makedirs(os.path.join(path_to_train, class_name), exist_ok=True)
    os.makedirs(os.path.join(path_to_test, class_name), exist_ok=True)
    os.makedirs(os.path.join(path_to_valid, class_name), exist_ok=True)

# %% [markdown]
# #Split Train - Valid - Test

# %%
# Chia dữ liệu thành tập train/test/valid
for class_name in classes:
    class_path = os.path.join(path_to_data, class_name)
    images = os.listdir(class_path)
    train_images, test_images = train_test_split(images, test_size=0.3, random_state=42) #train 14000(3500 1 class), test 6000
    test_images, valid_images = train_test_split(test_images, test_size=0.4, random_state=42) #test 3600 (900 1 class), valid 2400 (800)

    for image in train_images:
        src = os.path.join(class_path, image)
        dest = os.path.join(path_to_train, class_name, image)
        shutil.copy(src, dest)

    for image in test_images:
        src = os.path.join(class_path, image)
        dest = os.path.join(path_to_test, class_name, image)
        shutil.copy(src, dest)

    for image in valid_images:
        src = os.path.join(class_path, image)
        dest = os.path.join(path_to_valid, class_name, image)
        shutil.copy(src, dest)

# %% [markdown]
# #Show the amount of data

# %%
def viz_class(x, NoD):
    class_names = list(filter(lambda f: os.path.isdir(os.path.join(x, f)),
                              os.listdir(x)))
    class_dis = [len(os.listdir(x + f"/{name}")) for name in class_names]
    lk_dis = dict(zip(class_names, class_dis))
    print(f"Class Distribution:\n{lk_dis}")

    fig = px.bar(x=class_dis, y=class_names, color=class_names, width=1000)
    fig.update_layout({'title': {'text': f'{NoD}', 'x': 0.5}},
                      xaxis_title="Số lượng mẫu",
                      yaxis_title="Các lớp của Dataset")
    fig.show()

# %%
viz_class(path_to_train, "Train Set")
# Out:
# Class Distribution:
# {'0': 3500, '90': 3500, '180': 3500, '270': 3500}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b21f6630-552f-4e63-911a-50af106f00d1" class="plotly-graph-div" style="height:525px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b21f6630-552f-4e63-911a-50af106f00d1")) {                    Plotly.newPlot(                        "b21f6630-552f-4e63-911a-50af106f00d1",                        [{"alignmentgroup":"True","hovertemplate":"color=0\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"h","showlegend":true,"textposition":"auto","x":[3500],"xaxis":"x","y":["0"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=90\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"90","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"90","offsetgroup":"90","orientation":"h","showlegend":true,"textposition":"auto","x":[3500],"xaxis":"x","y":["90"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=180\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"180","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"180","offsetgroup":"180","orientation":"h","showlegend":true,"textposition":"auto","x":[3500],"xaxis":"x","y":["180"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=270\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"270","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"270","offsetgroup":"270","orientation":"h","showlegend":true,"textposition":"auto","x":[3500],"xaxis":"x","y":["270"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9 ...

# %%
viz_class(path_to_valid, "Valid Set")
# Out:
# Class Distribution:
# {'0': 600, '90': 600, '180': 600, '270': 600}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="edd521aa-3485-48b1-8568-0718aa5dff0b" class="plotly-graph-div" style="height:525px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edd521aa-3485-48b1-8568-0718aa5dff0b")) {                    Plotly.newPlot(                        "edd521aa-3485-48b1-8568-0718aa5dff0b",                        [{"alignmentgroup":"True","hovertemplate":"color=0\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"h","showlegend":true,"textposition":"auto","x":[600],"xaxis":"x","y":["0"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=90\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"90","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"90","offsetgroup":"90","orientation":"h","showlegend":true,"textposition":"auto","x":[600],"xaxis":"x","y":["90"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=180\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"180","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"180","offsetgroup":"180","orientation":"h","showlegend":true,"textposition":"auto","x":[600],"xaxis":"x","y":["180"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=270\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"270","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"270","offsetgroup":"270","orientation":"h","showlegend":true,"textposition":"auto","x":[600],"xaxis":"x","y":["270"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a" ...

# %%
viz_class(path_to_test, "Test Set")
# Out:
# Class Distribution:
# {'0': 900, '90': 900, '180': 900, '270': 900}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="77048723-d6dc-4a75-b0c0-731564291f20" class="plotly-graph-div" style="height:525px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77048723-d6dc-4a75-b0c0-731564291f20")) {                    Plotly.newPlot(                        "77048723-d6dc-4a75-b0c0-731564291f20",                        [{"alignmentgroup":"True","hovertemplate":"color=0\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"h","showlegend":true,"textposition":"auto","x":[900],"xaxis":"x","y":["0"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=90\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"90","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"90","offsetgroup":"90","orientation":"h","showlegend":true,"textposition":"auto","x":[900],"xaxis":"x","y":["90"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=180\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"180","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"180","offsetgroup":"180","orientation":"h","showlegend":true,"textposition":"auto","x":[900],"xaxis":"x","y":["180"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=270\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"270","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"270","offsetgroup":"270","orientation":"h","showlegend":true,"textposition":"auto","x":[900],"xaxis":"x","y":["270"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a" ...

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
  path_to_train,
  image_size=(224, 224),
  batch_size=10,
  shuffle= True)

def show_images(dataset):
  plt.figure(figsize=(16,8))
  plt.suptitle('Samples of Data', fontsize=24)
  for images, labels in dataset.take(1):
    for i in range(10):
      ax = plt.subplot(2, 5, i + 1)
      ax.imshow(images[i].numpy().astype("uint8"))
      ax.set_title(dataset.class_names[labels[i]], color = 'g')
      ax.axis("off")
  plt.show()

show_images(dataset)
# Out:
# Found 14000 files belonging to 4 classes.

# %% [markdown]
# #Xây dựng mô hình phân loại ảnh

# %% [markdown]
# ##Chuẩn bị dữ liệu

# %%
BASE_PATH = "Rotated_IM"

TRAIN_PATH = '/content/Train'
VALID_PATH = '/content/Valid'
TEST_PATH = '/content/Test'

CLASSES = ['Angle 0', 'Angle 180', 'Angle 270', 'Angle 90']

IMG_SIZE = (224, 224)

# %% [markdown]
# Ở phần classification có sử dụng horizontal và vertical để flip ảnh => nhắm đa dạng hóa mẫu dữ liệu cho mô hình có thể học tốt hơn. Nhưng đối với bài toán xác định góc quay thì không sử dụng được vì nó sẽ tốt trên mẫu này nhưng lại hại trên mẫu khác (VD: khi xoay ảnh của Sneaker hoặc Mouse thì ảnh hưởng không quá lớn nhưng khi flip trên Headphone và Pen thì các ảnh ở góc 90 và 270 sẽ gần như là trùng nhau => không sử dụng flip cho bài toán xác định góc xoay)

# %%
train_dataset = image_dataset_from_directory(
 Path.cwd() / BASE_PATH / TRAIN_PATH ,
 image_size=(224, 224),
 batch_size=128,
 label_mode='categorical')

validation_dataset = image_dataset_from_directory(
    Path.cwd() / BASE_PATH / VALID_PATH,
    image_size=(224, 224),
    batch_size=128,
    label_mode='categorical'
)

test_dataset = image_dataset_from_directory(
    Path.cwd() / BASE_PATH / TEST_PATH,
    image_size=(224, 224),
    batch_size=128,
    label_mode='categorical'
)

for images_batch, labels_batch in train_dataset:
 print("images batch shape:", images_batch.shape)
 print("labels batch shape:", labels_batch.shape)
 break
# Out:
# Found 14000 files belonging to 4 classes.
# Found 2400 files belonging to 4 classes.
# Found 3600 files belonging to 4 classes.
# images batch shape: (128, 224, 224, 3)
# labels batch shape: (128, 4)

# %% [markdown]
# ##Xây dựng mô hình

# %% [markdown]
# Model sẽ được dùng lại của bài classifier vì nó vốn rất tốt. Trước đó có thể hiện thực 2 bài toán classifier trên cùng 1 file nhưng vì dung lượng Ram có giới hạn nên phải chia thành 2 file.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense

def ResNet_5Thing(input_shape=(224, 224, 3), num_classes=4):
    # Tạo mô hình ResNet50 với trọng số được đào tạo trước
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

    # Đóng băng trọng số của mô hình ResNet50
    for layer in base_model.layers:
        layer.trainable = False

    # Tạo mô hình phân loại
    model = keras.Sequential([
        # Sử dụng mô hình ResNet50 làm phần trích xuất đặc trưng
        base_model,

        # Làm phẳng đầu ra của mô hình ResNet50
        GlobalAveragePooling2D(),

        # Tầng fully connected
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')  # Số lớp phân loại của bạn
    ])

    return model

# Sử dụng hàm để tạo mô hình
model = ResNet_5Thing()

# In thông tin mô hình
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)               262272
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 23850500 (90.98 MB)
# Trainable params: 262788 (1.00 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

callbacks = [keras.callbacks.ModelCheckpoint(
    filepath="5Thing_ResRotation.hdf5",
    save_best_only=True,
    monitor="val_loss",
    verbose=1)
]

# %% [markdown]
# Non-trainable params: 2944 là số lượng tham số không thể học do việc sử dụng chuẩn hóa **Batch**: 64*2 + 128*2 + 256*2 + 512*2 + 512*2 = 2944 (tương ứng cho từng tầng conv2d cộng lại nhân 2)​

# %%
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
    batch_size=512
)
# Out:
# Epoch 1/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4162 - accuracy: 0.8564
# Epoch 1: val_loss improved from inf to 0.34849, saving model to 5Thing_ResRotation.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 110/110 [==============================] - 57s 509ms/step - loss: 0.4162 - accuracy: 0.8564 - val_loss: 0.3485 - val_accuracy: 0.8800
# Epoch 2/30
# 110/110 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.9206
# Epoch 2: val_loss improved from 0.34849 to 0.32924, saving model to 5Thing_ResRotation.hdf5
# 110/110 [==============================] - 54s 482ms/step - loss: 0.2505 - accuracy: 0.9206 - val_loss: 0.3292 - val_accuracy: 0.8879
# Epoch 3/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1898 - accuracy: 0.9409
# Epoch 3: val_loss improved from 0.32924 to 0.25353, saving model to 5Thing_ResRotation.hdf5
# 110/110 [==============================] - 52s 465ms/step - loss: 0.1898 - accuracy: 0.9409 - val_loss: 0.2535 - val_accuracy: 0.9146
# Epoch 4/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9588
# Epoch 4: val_loss improved from 0.25353 to 0.21819, saving model to 5Thing_ResRotation.hdf5
# 110/110 [==============================] - 52s 464ms/step - loss: 0.1407 - accuracy: 0.9588 - val_loss: 0.2182 - val_accuracy: 0.9254
# Epoch 5/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9660
# Epoch 5: val_loss improved from 0.21819 to 0.21124, saving model to 5Thing_ResRotation.hdf5
# 110/110 [==============================] - 52s 463ms/step - loss: 0.1162 - accuracy: 0.9660 - val_loss: 0.2112 - val_accuracy: 0.9271
# Epoch 6/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 0.9745
# Epoch 6: val_loss improved from 0.21124 to 0.20490, saving model to 5Thing_ResRotation.hdf5
# 110/110 [==============================] - 51s 457ms/step - loss: 0.0888 - accuracy: 0.9745 - val_loss: 0.2049 - val_accuracy: 0.9317
# Epoch 7/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9838
# Epoch 7: val_loss did not improve from 0.20490
# 110/110 [==============================] - 54s 477ms/step - loss: 0.0708 - accuracy: 0.9838 - val_loss: 0.2094 - val_accuracy: 0.9308
# Epoch 8/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9862
# Epoch 8: val_loss did not improve from 0.20490
# 110/110 [==============================] - 51s 462ms/step - loss: 0.0571 - accuracy: 0.9862 - val_loss: 0.2080 - val_accuracy: 0.9329
# Epoch 9/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9893
# Epoch 9: val_loss did not improve from 0.20490
# 110/110 [==============================] - 51s 455ms/step - loss: 0.0492 - accuracy: 0.9893 - val_loss: 0.2308 - val_accuracy: 0.9242
# Epoch 10/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0438 - accuracy: 0.9899
# Epoch 10: val_loss improved from 0.20490 to 0.19760, saving model to 5Thing_ResRotation.hdf5
# 110/110 [==============================] - 51s 461ms/step - loss: 0.0438 - accuracy: 0.9899 - val_loss: 0.1976 - val_accuracy: 0.9429
# Epoch 11/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9936
# Epoch 11: val_loss did not improve from 0.19760
# 110/110 [==============================] - 50s 454ms/step - loss: 0.0329 - accuracy: 0.9936 - val_loss: 0.2099 - val_accuracy: 0.9337
# Epoch 12/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9961
# Epoch 12: val_loss did not improve from 0.19760
# 110/110 [==============================] - 53s 479ms/step - loss: 0.0255 - accuracy: 0.9961 - val_loss: 0.2106 - val_accuracy: 0.9400
# Epoch 13/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9980
# Epoch 13: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 460ms/step - loss: 0.0180 - accuracy: 0.9980 - val_loss: 0.2226 - val_accuracy: 0.9350
# Epoch 14/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9960
# Epoch 14: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 456ms/step - loss: 0.0227 - accuracy: 0.9960 - val_loss: 0.2458 - val_accuracy: 0.9317
# Epoch 15/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9989
# Epoch 15: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 459ms/step - loss: 0.0135 - accuracy: 0.9989 - val_loss: 0.2209 - val_accuracy: 0.9413
# Epoch 16/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9991
# Epoch 16: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 455ms/step - loss: 0.0110 - accuracy: 0.9991 - val_loss: 0.2252 - val_accuracy: 0.9421
# Epoch 17/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9991
# Epoch 17: val_loss did not improve from 0.19760
# 110/110 [==============================] - 53s 479ms/step - loss: 0.0108 - accuracy: 0.9991 - val_loss: 0.2410 - val_accuracy: 0.9379
# Epoch 18/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9994
# Epoch 18: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 462ms/step - loss: 0.0080 - accuracy: 0.9994 - val_loss: 0.2374 - val_accuracy: 0.9400
# Epoch 19/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9997
# Epoch 19: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 455ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.2299 - val_accuracy: 0.9425
# Epoch 20/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9998
# Epoch 20: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 455ms/step - loss: 0.0049 - accuracy: 0.9998 - val_loss: 0.2286 - val_accuracy: 0.9471
# Epoch 21/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9999
# Epoch 21: val_loss did not improve from 0.19760
# 110/110 [==============================] - 50s 453ms/step - loss: 0.0038 - accuracy: 0.9999 - val_loss: 0.2360 - val_accuracy: 0.9446
# Epoch 22/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9999
# Epoch 22: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 459ms/step - loss: 0.0037 - accuracy: 0.9999 - val_loss: 0.2364 - val_accuracy: 0.9425
# Epoch 23/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9991
# Epoch 23: val_loss did not improve from 0.19760
# 110/110 [==============================] - 50s 453ms/step - loss: 0.0065 - accuracy: 0.9991 - val_loss: 0.2508 - val_accuracy: 0.9375
# Epoch 24/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9997
# Epoch 24: val_loss did not improve from 0.19760
# 110/110 [==============================] - 53s 475ms/step - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.2458 - val_accuracy: 0.9425
# Epoch 25/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9996
# Epoch 25: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 461ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 0.2533 - val_accuracy: 0.9392
# Epoch 26/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9992
# Epoch 26: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 461ms/step - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.2535 - val_accuracy: 0.9404
# Epoch 27/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9779
# Epoch 27: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 457ms/step - loss: 0.0614 - accuracy: 0.9779 - val_loss: 0.3277 - val_accuracy: 0.9254
# Epoch 28/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1009 - accuracy: 0.9649
# Epoch 28: val_loss did not improve from 0.19760
# 110/110 [==============================] - 53s 479ms/step - loss: 0.1009 - accuracy: 0.9649 - val_loss: 0.3068 - val_accuracy: 0.9296
# Epoch 29/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9907
# Epoch 29: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 459ms/step - loss: 0.0273 - accuracy: 0.9907 - val_loss: 0.2966 - val_accuracy: 0.9337
# Epoch 30/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9979
# Epoch 30: val_loss did not improve from 0.19760
# 110/110 [==============================] - 51s 457ms/step - loss: 0.0091 - accuracy: 0.9979 - val_loss: 0.2569 - val_accuracy: 0.9458

# %% [markdown]
# ##Biểu đồ và kết quả huấn luyện

# %%
# Vẽ biểu đồ huấn luyện
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, accuracy, label="Training accuracy")
plt.plot(epochs, val_accuracy, label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label="Training loss")
plt.plot(epochs, val_loss, label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test accuracy: {test_accuracy:.2f}")
# Out:
# 29/29 [==============================] - 13s 405ms/step - loss: 0.2316 - accuracy: 0.9458
# Test accuracy: 0.95

# %% [markdown]
# #Lưu model

# %%
# drive_path = '/content/gdrive/MyDrive/DeepLearning/Đồ án/HDF5'
# model_hdf5_path = drive_path + '/5Thing_ResRotation.hdf5'
# model.save(model_hdf5_path)
# print("Model đã được lưu vào:", model_hdf5_path)
# Out:
# Model đã được lưu vào: /content/gdrive/MyDrive/DeepLearning/Đồ án/5Thing_ResRotation.hdf5

# %% [markdown]
# #Show prediction

# %%
def show_predictions(dataset, model, class_names):
    count = 0
    fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(16, 8))
    for images, labels in dataset:
        # Chuyển đổi one-hot encoding thành nhãn
        true_labels = np.argmax(labels, axis=1)

        # Dự đoán trên tập dữ liệu
        predictions = model.predict(images)

        # Chuyển đổi one-hot encoding của dự đoán thành nhãn dự đoán
        predicted_labels = np.argmax(predictions, axis=1)

        # Lấy confidence
        confidence = np.max(predictions, axis=1)

        for i in range(images.shape[0]):  # Use images.shape[0] instead of images_np.shape[0]
            if count >= 10:
                break

            ax = axes[count // 5, count % 5]
            ax.imshow(images[i].numpy().astype(np.uint8))  # Convert EagerTensor to NumPy array

            if predicted_labels[i] == true_labels[i]:
                color = 'g'
            else:
                color = 'r'

            ax.set_title(f"Pred: {class_names[predicted_labels[i]]}-({class_names[true_labels[i]]})({confidence[i]:.2f})", color=color, size=10)
            ax.set(xticks=[], yticks=[])
            count += 1

        if count >= 10:
            break

    title = "Prediction results for images in a batch"
    fig.suptitle(title)
    plt.show()

# %%
show_predictions(test_dataset, model, CLASSES)
# Out:
# 4/4 [==============================] - 2s 70ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load model
loaded_model = load_model('5Thing_ResRotation.hdf5')

# Function to evaluate and print classification report
def evaluate_model(model, dataset):
    true_labels = []
    predicted_labels = []

    for images, labels in dataset:
        true_labels.extend(np.argmax(labels, axis=1))  # Convert one-hot encoding to labels
        predictions = model.predict(images)
        predicted_labels.extend(np.argmax(predictions, axis=1))

    print("Classification Report:")
    print(classification_report(true_labels, predicted_labels))

    # Plot confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASSES, yticklabels=CLASSES)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Evaluate on the test dataset
evaluate_model(loaded_model, test_dataset)
# Out:
# 4/4 [==============================] - 2s 120ms/step
# 4/4 [==============================] - 0s 91ms/step
# 4/4 [==============================] - 0s 102ms/step
# 4/4 [==============================] - 0s 99ms/step
# 4/4 [==============================] - 0s 99ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 104ms/step
# 4/4 [==============================] - 0s 101ms/step
# 4/4 [==============================] - 0s 95ms/step
# 4/4 [==============================] - 0s 99ms/step
# 4/4 [==============================] - 0s 99ms/step
# 4/4 [==============================] - 0s 98ms/step
# 4/4 [==============================] - 0s 98ms/step
# 4/4 [==============================] - 0s 83ms/step
# 4/4 [==============================] - 0s 86ms/step
# 4/4 [==============================] - 0s 89ms/step
# 4/4 [==============================] - 0s 89ms/step
# 4/4 [==============================] - 0s 88ms/step
# 4/4 [==============================] - 0s 87ms/step
# 4/4 [==============================] - 0s 90ms/step
# 4/4 [==============================] - 0s 90ms/step
# 4/4 [==============================] - 0s 90ms/step
# 4/4 [==============================] - 0s 90ms/step
# 4/4 [==============================] - 0s 89ms/step
# 4/4 [==============================] - 0s 90ms/step
# 4/4 [==============================] - 0s 89ms/step
# 4/4 [==============================] - 0s 84ms/step
# 4/4 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 1s 938ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       900
#            1       0.95      0.96      0.96       900
#            2       0.92      0.94      0.93       900
#            3       0.95      0.93      0.94       900
#
#     accuracy                           0.95      3600
#    macro avg       0.95      0.95      0.95      3600
# weighted avg       0.95      0.95      0.95      3600
