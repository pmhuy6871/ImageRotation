# %% [markdown]
# #Yêu cầu chủ đề.
#
# Xây dựng phần mềm nhận dạng 5 đối tượng trong phòng
# * a. Xây dựng, thu thập tập dữ liệu các đối tượng cần nhận dạng
# * b. Phân lớp các đối tượng trên
# * c. Tìm gốc quay của đối tượng
# * d. Triển khai mô hình (web, desktop)

# %% [markdown]
# # Giới thiệu.
# - Dataset được thu thập từ 5 vật dụng định sẵn thường có trong phòng: Bottle, Headphone, Mouse, Pen, Sneaker.
# - Thu thập bằng cách tải ảnh và thu thập từ các dataset.

# %% [markdown]
# # 1 - Chuẩn bị dữ liệu.

# %% [markdown]
# Dataset nhóm sử dụng có 3 phần: train, test và valid.
# - Dataset ban đầu được chia 7 phần train 3 phần test, train 3500(700 1 class), test 1500.
# - Sau đó từ tập test (1500) chia thành 6 phần test 900 (180 1 class), 4 phần valid 600 (120).
# - Các ảnh này đã được xoay theo 4 góc để mô hình có thể học đa dạng và phân loại tốt hơn với nhiều góc độ của vật

# %% [markdown]
# * Mục tiêu chính của bài toán phân loại này là tìm ra mối quan hệ, mẫu hoặc đặc trưng của các vật để có thể dự đoán nhãn của các ảnh chưa được biết trước.

# %% [markdown]
# ## 1.1 Tải và uzip Dataset.

# %%
# %%shell
# #https://drive.google.com/file/d/12eKyOde5LgYbUwqamA1iTIzq9pgBxpXY/view?usp=sharing
# gdown -q 12eKyOde5LgYbUwqamA1iTIzq9pgBxpXY
# rm -rf /content/Data
# mkdir -p /content/Data
# unzip -q 5Thing.zip -d /content/Data

# %% [markdown]
# #Import libary

# %%
import os
import shutil
import random
import progressbar
import cv2
import imutils
from imutils import paths
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from joblib import dump, load
import plotly.express as px
from google.colab import drive
from keras.models import load_model

import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical, img_to_array, load_img
from keras.applications import imagenet_utils
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, BatchNormalization
from tensorflow.keras import layers, Sequential, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# # Mount Google Drive
# drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Đường dẫn đến thư mục chứa dữ liệu
path_to_data = '/content/Data/5Thing'

# Đường dẫn đến thư mục chứa dữ liệu đã được chia
path_to_train = '/content/Train'
path_to_test = '/content/Test'
path_to_valid = '/content/Valid'

# Tạo các thư mục nếu chúng không tồn tại
os.makedirs(path_to_train, exist_ok=True)
os.makedirs(path_to_test, exist_ok=True)
os.makedirs(path_to_valid, exist_ok=True)

# Tạo thư mục train/test/valid cho từng class
classes = os.listdir(path_to_data)
for class_name in classes:
    os.makedirs(os.path.join(path_to_train, class_name), exist_ok=True)
    os.makedirs(os.path.join(path_to_test, class_name), exist_ok=True)
    os.makedirs(os.path.join(path_to_valid, class_name), exist_ok=True)

# %% [markdown]
# #Split Train - Valid - Test

# %%
# Chia dữ liệu thành tập train/test/valid
for class_name in classes:
    class_path = os.path.join(path_to_data, class_name)
    images = os.listdir(class_path)
    train_images, test_images = train_test_split(images, test_size=0.3, random_state=42) #train 3500(700 1 class), test 1500
    test_images, valid_images = train_test_split(test_images, test_size=0.4, random_state=42) #test 900 (180 1 class), valid 600 (120)

    for image in train_images:
        src = os.path.join(class_path, image)
        dest = os.path.join(path_to_train, class_name, image)
        shutil.copy(src, dest)

    for image in test_images:
        src = os.path.join(class_path, image)
        dest = os.path.join(path_to_test, class_name, image)
        shutil.copy(src, dest)

    for image in valid_images:
        src = os.path.join(class_path, image)
        dest = os.path.join(path_to_valid, class_name, image)
        shutil.copy(src, dest)

# %% [markdown]
# #Show the amount of data

# %%
def viz_class(x, NoD):
    class_names = list(filter(lambda f: os.path.isdir(os.path.join(x, f)),
                              os.listdir(x)))
    class_dis = [len(os.listdir(x + f"/{name}")) for name in class_names]
    lk_dis = dict(zip(class_names, class_dis))
    print(f"Class Distribution:\n{lk_dis}")

    fig = px.bar(x=class_dis, y=class_names, color=class_names, width=1000)
    fig.update_layout({'title': {'text': f'{NoD}', 'x': 0.5}},
                      xaxis_title="Số lượng mẫu",
                      yaxis_title="Các lớp của Dataset")
    fig.show()

# %%
viz_class(path_to_train, "Train Set")
# Out:
# Class Distribution:
# {'Bottle': 700, 'Headphone': 700, 'Mouse': 700, 'Shoes': 700, 'Pen': 700}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6b82ee62-8be7-4c9a-9fc0-83d108843ea9" class="plotly-graph-div" style="height:525px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b82ee62-8be7-4c9a-9fc0-83d108843ea9")) {                    Plotly.newPlot(                        "6b82ee62-8be7-4c9a-9fc0-83d108843ea9",                        [{"alignmentgroup":"True","hovertemplate":"color=Bottle\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bottle","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bottle","offsetgroup":"Bottle","orientation":"h","showlegend":true,"textposition":"auto","x":[700],"xaxis":"x","y":["Bottle"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Headphone\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Headphone","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Headphone","offsetgroup":"Headphone","orientation":"h","showlegend":true,"textposition":"auto","x":[700],"xaxis":"x","y":["Headphone"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mouse\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mouse","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Mouse","offsetgroup":"Mouse","orientation":"h","showlegend":true,"textposition":"auto","x":[700],"xaxis":"x","y":["Mouse"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Shoes\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shoes","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Shoes","offsetgroup":"Shoes","orientation":"h","showlegend":true,"textposition":"auto","x":[700],"xaxis":"x","y":["Shoes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Pen\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pen","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Pen","offsetgroup":"Pen","orientation":"h","showlegend":true,"textposition":"auto","x":[700],"xaxis":"x","y":["Pen"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888 ...

# %%
viz_class(path_to_valid, "Valid Set")
# Out:
# Class Distribution:
# {'Bottle': 120, 'Headphone': 120, 'Mouse': 120, 'Shoes': 120, 'Pen': 120}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b8b991ec-03b4-4d32-aeae-41f1040ddb12" class="plotly-graph-div" style="height:525px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8b991ec-03b4-4d32-aeae-41f1040ddb12")) {                    Plotly.newPlot(                        "b8b991ec-03b4-4d32-aeae-41f1040ddb12",                        [{"alignmentgroup":"True","hovertemplate":"color=Bottle\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bottle","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bottle","offsetgroup":"Bottle","orientation":"h","showlegend":true,"textposition":"auto","x":[120],"xaxis":"x","y":["Bottle"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Headphone\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Headphone","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Headphone","offsetgroup":"Headphone","orientation":"h","showlegend":true,"textposition":"auto","x":[120],"xaxis":"x","y":["Headphone"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mouse\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mouse","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Mouse","offsetgroup":"Mouse","orientation":"h","showlegend":true,"textposition":"auto","x":[120],"xaxis":"x","y":["Mouse"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Shoes\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shoes","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Shoes","offsetgroup":"Shoes","orientation":"h","showlegend":true,"textposition":"auto","x":[120],"xaxis":"x","y":["Shoes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Pen\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pen","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Pen","offsetgroup":"Pen","orientation":"h","showlegend":true,"textposition":"auto","x":[120],"xaxis":"x","y":["Pen"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888 ...

# %%
viz_class(path_to_test, "Test Set")
# Out:
# Class Distribution:
# {'Bottle': 180, 'Headphone': 180, 'Mouse': 180, 'Shoes': 180, 'Pen': 180}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3b84f14c-d75d-4f26-a910-80f730ee0c90" class="plotly-graph-div" style="height:525px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b84f14c-d75d-4f26-a910-80f730ee0c90")) {                    Plotly.newPlot(                        "3b84f14c-d75d-4f26-a910-80f730ee0c90",                        [{"alignmentgroup":"True","hovertemplate":"color=Bottle\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bottle","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bottle","offsetgroup":"Bottle","orientation":"h","showlegend":true,"textposition":"auto","x":[180],"xaxis":"x","y":["Bottle"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Headphone\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Headphone","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Headphone","offsetgroup":"Headphone","orientation":"h","showlegend":true,"textposition":"auto","x":[180],"xaxis":"x","y":["Headphone"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mouse\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mouse","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Mouse","offsetgroup":"Mouse","orientation":"h","showlegend":true,"textposition":"auto","x":[180],"xaxis":"x","y":["Mouse"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Shoes\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shoes","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Shoes","offsetgroup":"Shoes","orientation":"h","showlegend":true,"textposition":"auto","x":[180],"xaxis":"x","y":["Shoes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Pen\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pen","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Pen","offsetgroup":"Pen","orientation":"h","showlegend":true,"textposition":"auto","x":[180],"xaxis":"x","y":["Pen"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888 ...

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
  path_to_train,
  image_size=(224, 224),
  batch_size=10,
  shuffle= True)

def show_images(dataset):
  plt.figure(figsize=(16,8))
  plt.suptitle('Samples of Data', fontsize=24)
  for images, labels in dataset.take(1):
    for i in range(10):
      ax = plt.subplot(2, 5, i + 1)
      ax.imshow(images[i].numpy().astype("uint8"))
      ax.set_title(dataset.class_names[labels[i]], color = 'g')
      ax.axis("off")
  plt.show()

show_images(dataset)
# Out:
# Found 3500 files belonging to 5 classes.

# %% [markdown]
# #Xây dựng mô hình phân loại ảnh

# %% [markdown]
# ##Chuẩn bị dữ liệu

# %%
BASE_PATH = "5Thing"

TRAIN_PATH = '/content/Train'
VALID_PATH = '/content/Valid'
TEST_PATH = '/content/Test'

CLASSES = ['Bottle', 'Headphone', 'Mouse', 'Pen', 'Sneaker']

IMG_SIZE = (224, 224)

# %%
train_dataset = image_dataset_from_directory(
 Path.cwd() / BASE_PATH / TRAIN_PATH ,
 image_size=(224, 224),
 batch_size=32,
 label_mode='categorical')

validation_dataset = image_dataset_from_directory(
    Path.cwd() / BASE_PATH / VALID_PATH,
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

test_dataset = image_dataset_from_directory(
    Path.cwd() / BASE_PATH / TEST_PATH,
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

for images_batch, labels_batch in train_dataset:
 print("images batch shape:", images_batch.shape)
 print("labels batch shape:", labels_batch.shape)
 break
# Out:
# Found 3500 files belonging to 5 classes.
# Found 600 files belonging to 5 classes.
# Found 900 files belonging to 5 classes.
# images batch shape: (32, 224, 224, 3)
# labels batch shape: (32, 5)

# %% [markdown]
# ##Xây dựng mô hình

# %% [markdown]
# Mô hình này được tạo ra sau khi tìm hiểu thêm là các lớp BatchNorm (Chuẩn hoá), Maxpooling, Droput có thể giúp cho mô hình tốt hơn. Mô hình này hoàn toàn là sự ngẫu nhiên thử nghiệm và nó mang lại kết quả tốt nên giữ và không chỉnh sửa thêm

# %%
def CNN_5Thing():
    model = keras.Sequential([
        keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(224, 224, 3)),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D(2, 2),
        keras.layers.Dropout(0.2),

        keras.layers.Conv2D(128, (3, 3), activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D(2, 2),
        keras.layers.Dropout(0.2),

        keras.layers.Conv2D(256, (3, 3), activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D(2, 2),
        keras.layers.Dropout(0.2),

        keras.layers.Conv2D(512, (3, 3), activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D(2, 2),
        keras.layers.Dropout(0.2),

        keras.layers.Conv2D(512, (3, 3), activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D(2, 2),
        keras.layers.Dropout(0.2),

        keras.layers.Flatten(),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(5, activation='softmax')
    ])
    return model

# %%
model = CNN_5Thing()

print(model.summary())

model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

callbacks = [keras.callbacks.ModelCheckpoint(
    filepath="5Thing.hdf5",
    save_best_only=True,
    monitor="val_loss",
    verbose=1)
]
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  batch_normalization (Batch  (None, 222, 222, 64)      256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 64)      0
#  D)
#
#  dropout (Dropout)           (None, 111, 111, 64)      0
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 128)     73856
#
#  batch_normalization_1 (Bat  (None, 109, 109, 128)     512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 54, 54, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 256)       295168
#
#  batch_normalization_2 (Bat  (None, 52, 52, 256)       1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 256)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 26, 26, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 512)       1180160
#
#  batch_normalization_3 (Bat  (None, 24, 24, 512)       2048
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 512)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 12, 12, 512)       0
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 512)       2359808
#
#  batch_normalization_4 (Bat  (None, 10, 10, 512)       2048
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 512)         0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 5, 5, 512)         0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 128)               1638528
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 5555845 (21.19 MB)
# Trainable params: 5552901 (21.18 MB)
# Non-trainable params: 2944 (11.50 KB)
# _________________________________________________________________
# None

# %% [markdown]
# Non-trainable params: 2944 là số lượng tham số không thể học do việc sử dụng chuẩn hóa **Batch**: 64*2 + 128*2 + 256*2 + 512*2 + 512*2 = 2944 (tương ứng cho từng tầng conv2d cộng lại nhân 2)​

# %%
history = model.fit(
    train_dataset,
    epochs=60,
    validation_data=validation_dataset,
    callbacks=callbacks,
    batch_size=128
)
# Out:
# Epoch 1/60
# 110/110 [==============================] - ETA: 0s - loss: 2.0375 - accuracy: 0.5531
# Epoch 1: val_loss improved from inf to 4.98490, saving model to 5Thing.hdf5
# 110/110 [==============================] - 51s 308ms/step - loss: 2.0375 - accuracy: 0.5531 - val_loss: 4.9849 - val_accuracy: 0.3483
# Epoch 2/60
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 110/110 [==============================] - ETA: 0s - loss: 0.9484 - accuracy: 0.6597
# Epoch 2: val_loss improved from 4.98490 to 0.97309, saving model to 5Thing.hdf5
# 110/110 [==============================] - 32s 291ms/step - loss: 0.9484 - accuracy: 0.6597 - val_loss: 0.9731 - val_accuracy: 0.6600
# Epoch 3/60
# 110/110 [==============================] - ETA: 0s - loss: 0.7951 - accuracy: 0.7066
# Epoch 3: val_loss improved from 0.97309 to 0.87575, saving model to 5Thing.hdf5
# 110/110 [==============================] - 32s 293ms/step - loss: 0.7951 - accuracy: 0.7066 - val_loss: 0.8757 - val_accuracy: 0.7183
# Epoch 4/60
# 110/110 [==============================] - ETA: 0s - loss: 0.8002 - accuracy: 0.7303
# Epoch 4: val_loss did not improve from 0.87575
# 110/110 [==============================] - 32s 294ms/step - loss: 0.8002 - accuracy: 0.7303 - val_loss: 1.6060 - val_accuracy: 0.7383
# Epoch 5/60
# 110/110 [==============================] - ETA: 0s - loss: 0.6541 - accuracy: 0.7600
# Epoch 5: val_loss improved from 0.87575 to 0.56767, saving model to 5Thing.hdf5
# 110/110 [==============================] - 32s 293ms/step - loss: 0.6541 - accuracy: 0.7600 - val_loss: 0.5677 - val_accuracy: 0.8083
# Epoch 6/60
# 110/110 [==============================] - ETA: 0s - loss: 0.5499 - accuracy: 0.8077
# Epoch 6: val_loss did not improve from 0.56767
# 110/110 [==============================] - 33s 295ms/step - loss: 0.5499 - accuracy: 0.8077 - val_loss: 0.7588 - val_accuracy: 0.7033
# Epoch 7/60
# 110/110 [==============================] - ETA: 0s - loss: 0.5283 - accuracy: 0.8169
# Epoch 7: val_loss did not improve from 0.56767
# 110/110 [==============================] - 33s 294ms/step - loss: 0.5283 - accuracy: 0.8169 - val_loss: 0.5717 - val_accuracy: 0.8050
# Epoch 8/60
# 110/110 [==============================] - ETA: 0s - loss: 0.4709 - accuracy: 0.8300
# Epoch 8: val_loss improved from 0.56767 to 0.47645, saving model to 5Thing.hdf5
# 110/110 [==============================] - 33s 294ms/step - loss: 0.4709 - accuracy: 0.8300 - val_loss: 0.4764 - val_accuracy: 0.8533
# Epoch 9/60
# 110/110 [==============================] - ETA: 0s - loss: 0.4151 - accuracy: 0.8500
# Epoch 9: val_loss improved from 0.47645 to 0.44976, saving model to 5Thing.hdf5
# 110/110 [==============================] - 33s 296ms/step - loss: 0.4151 - accuracy: 0.8500 - val_loss: 0.4498 - val_accuracy: 0.8767
# Epoch 10/60
# 110/110 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8660
# Epoch 10: val_loss did not improve from 0.44976
# 110/110 [==============================] - 32s 293ms/step - loss: 0.3649 - accuracy: 0.8660 - val_loss: 0.4811 - val_accuracy: 0.8500
# Epoch 11/60
# 110/110 [==============================] - ETA: 0s - loss: 0.3576 - accuracy: 0.8737
# Epoch 11: val_loss did not improve from 0.44976
# 110/110 [==============================] - 32s 291ms/step - loss: 0.3576 - accuracy: 0.8737 - val_loss: 0.5632 - val_accuracy: 0.8283
# Epoch 12/60
# 110/110 [==============================] - ETA: 0s - loss: 0.3272 - accuracy: 0.8846
# Epoch 12: val_loss did not improve from 0.44976
# 110/110 [==============================] - 32s 291ms/step - loss: 0.3272 - accuracy: 0.8846 - val_loss: 0.5650 - val_accuracy: 0.8583
# Epoch 13/60
# 110/110 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8871
# Epoch 13: val_loss did not improve from 0.44976
# 110/110 [==============================] - 32s 290ms/step - loss: 0.3005 - accuracy: 0.8871 - val_loss: 0.4589 - val_accuracy: 0.8683
# Epoch 14/60
# 110/110 [==============================] - ETA: 0s - loss: 0.2785 - accuracy: 0.9014
# Epoch 14: val_loss improved from 0.44976 to 0.41442, saving model to 5Thing.hdf5
# 110/110 [==============================] - 32s 292ms/step - loss: 0.2785 - accuracy: 0.9014 - val_loss: 0.4144 - val_accuracy: 0.8567
# Epoch 15/60
# 110/110 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9091
# Epoch 15: val_loss improved from 0.41442 to 0.39256, saving model to 5Thing.hdf5
# 110/110 [==============================] - 33s 296ms/step - loss: 0.2565 - accuracy: 0.9091 - val_loss: 0.3926 - val_accuracy: 0.8900
# Epoch 16/60
# 110/110 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9137
# Epoch 16: val_loss did not improve from 0.39256
# 110/110 [==============================] - 33s 293ms/step - loss: 0.2411 - accuracy: 0.9137 - val_loss: 0.5737 - val_accuracy: 0.8500
# Epoch 17/60
# 110/110 [==============================] - ETA: 0s - loss: 0.2585 - accuracy: 0.9114
# Epoch 17: val_loss did not improve from 0.39256
# 110/110 [==============================] - 32s 291ms/step - loss: 0.2585 - accuracy: 0.9114 - val_loss: 0.6275 - val_accuracy: 0.8383
# Epoch 18/60
# 110/110 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.9189
# Epoch 18: val_loss did not improve from 0.39256
# 110/110 [==============================] - 32s 292ms/step - loss: 0.2525 - accuracy: 0.9189 - val_loss: 0.4238 - val_accuracy: 0.8900
# Epoch 19/60
# 110/110 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9306
# Epoch 19: val_loss did not improve from 0.39256
# 110/110 [==============================] - 32s 291ms/step - loss: 0.2176 - accuracy: 0.9306 - val_loss: 0.4608 - val_accuracy: 0.8767
# Epoch 20/60
# 110/110 [==============================] - ETA: 0s - loss: 0.2073 - accuracy: 0.9263
# Epoch 20: val_loss improved from 0.39256 to 0.34237, saving model to 5Thing.hdf5
# 110/110 [==============================] - 32s 293ms/step - loss: 0.2073 - accuracy: 0.9263 - val_loss: 0.3424 - val_accuracy: 0.9283
# Epoch 21/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9454
# Epoch 21: val_loss improved from 0.34237 to 0.30685, saving model to 5Thing.hdf5
# 110/110 [==============================] - 32s 294ms/step - loss: 0.1426 - accuracy: 0.9454 - val_loss: 0.3069 - val_accuracy: 0.9183
# Epoch 22/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9511
# Epoch 22: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 294ms/step - loss: 0.1486 - accuracy: 0.9511 - val_loss: 0.4013 - val_accuracy: 0.8967
# Epoch 23/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1595 - accuracy: 0.9463
# Epoch 23: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 292ms/step - loss: 0.1595 - accuracy: 0.9463 - val_loss: 0.3783 - val_accuracy: 0.9167
# Epoch 24/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9486
# Epoch 24: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 292ms/step - loss: 0.1550 - accuracy: 0.9486 - val_loss: 0.3581 - val_accuracy: 0.9217
# Epoch 25/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9537
# Epoch 25: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 291ms/step - loss: 0.1219 - accuracy: 0.9537 - val_loss: 0.3144 - val_accuracy: 0.9250
# Epoch 26/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9557
# Epoch 26: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 292ms/step - loss: 0.1261 - accuracy: 0.9557 - val_loss: 0.3784 - val_accuracy: 0.9133
# Epoch 27/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.9517
# Epoch 27: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 291ms/step - loss: 0.1687 - accuracy: 0.9517 - val_loss: 0.4712 - val_accuracy: 0.9017
# Epoch 28/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1785 - accuracy: 0.9440
# Epoch 28: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 294ms/step - loss: 0.1785 - accuracy: 0.9440 - val_loss: 0.5270 - val_accuracy: 0.8783
# Epoch 29/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9537
# Epoch 29: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 292ms/step - loss: 0.1475 - accuracy: 0.9537 - val_loss: 0.6468 - val_accuracy: 0.8583
# Epoch 30/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9489
# Epoch 30: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.1685 - accuracy: 0.9489 - val_loss: 0.5033 - val_accuracy: 0.8933
# Epoch 31/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9634
# Epoch 31: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0991 - accuracy: 0.9634 - val_loss: 0.3202 - val_accuracy: 0.9300
# Epoch 32/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9706
# Epoch 32: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 291ms/step - loss: 0.0791 - accuracy: 0.9706 - val_loss: 0.3907 - val_accuracy: 0.9150
# Epoch 33/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9763
# Epoch 33: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 291ms/step - loss: 0.0699 - accuracy: 0.9763 - val_loss: 0.4249 - val_accuracy: 0.9250
# Epoch 34/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9683
# Epoch 34: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 290ms/step - loss: 0.1017 - accuracy: 0.9683 - val_loss: 0.4404 - val_accuracy: 0.9083
# Epoch 35/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9717
# Epoch 35: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 290ms/step - loss: 0.0903 - accuracy: 0.9717 - val_loss: 0.3808 - val_accuracy: 0.9167
# Epoch 36/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9666
# Epoch 36: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 292ms/step - loss: 0.0971 - accuracy: 0.9666 - val_loss: 0.5055 - val_accuracy: 0.9117
# Epoch 37/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9629
# Epoch 37: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 292ms/step - loss: 0.1266 - accuracy: 0.9629 - val_loss: 0.5947 - val_accuracy: 0.8950
# Epoch 38/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9643
# Epoch 38: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.1047 - accuracy: 0.9643 - val_loss: 0.4098 - val_accuracy: 0.9150
# Epoch 39/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9557
# Epoch 39: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.1502 - accuracy: 0.9557 - val_loss: 0.5131 - val_accuracy: 0.8650
# Epoch 40/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9651
# Epoch 40: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 288ms/step - loss: 0.1147 - accuracy: 0.9651 - val_loss: 0.4539 - val_accuracy: 0.9000
# Epoch 41/60
# 110/110 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9594
# Epoch 41: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 288ms/step - loss: 0.1246 - accuracy: 0.9594 - val_loss: 0.5133 - val_accuracy: 0.8933
# Epoch 42/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9760
# Epoch 42: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0850 - accuracy: 0.9760 - val_loss: 0.4693 - val_accuracy: 0.9083
# Epoch 43/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9743
# Epoch 43: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0714 - accuracy: 0.9743 - val_loss: 0.5160 - val_accuracy: 0.9133
# Epoch 44/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9783
# Epoch 44: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 288ms/step - loss: 0.0641 - accuracy: 0.9783 - val_loss: 0.4331 - val_accuracy: 0.9233
# Epoch 45/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9840
# Epoch 45: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 287ms/step - loss: 0.0530 - accuracy: 0.9840 - val_loss: 0.8450 - val_accuracy: 0.8450
# Epoch 46/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9786
# Epoch 46: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0683 - accuracy: 0.9786 - val_loss: 0.8071 - val_accuracy: 0.8450
# Epoch 47/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9806
# Epoch 47: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 288ms/step - loss: 0.0636 - accuracy: 0.9806 - val_loss: 0.8907 - val_accuracy: 0.8767
# Epoch 48/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9749
# Epoch 48: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 291ms/step - loss: 0.0732 - accuracy: 0.9749 - val_loss: 0.4399 - val_accuracy: 0.9350
# Epoch 49/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9857
# Epoch 49: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0508 - accuracy: 0.9857 - val_loss: 0.4846 - val_accuracy: 0.9100
# Epoch 50/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9851
# Epoch 50: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 290ms/step - loss: 0.0489 - accuracy: 0.9851 - val_loss: 0.4755 - val_accuracy: 0.9250
# Epoch 51/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9866
# Epoch 51: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0378 - accuracy: 0.9866 - val_loss: 0.3623 - val_accuracy: 0.9400
# Epoch 52/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9863
# Epoch 52: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 288ms/step - loss: 0.0436 - accuracy: 0.9863 - val_loss: 0.4036 - val_accuracy: 0.9333
# Epoch 53/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9837
# Epoch 53: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0474 - accuracy: 0.9837 - val_loss: 0.3720 - val_accuracy: 0.9317
# Epoch 54/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9869
# Epoch 54: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0346 - accuracy: 0.9869 - val_loss: 0.4401 - val_accuracy: 0.9250
# Epoch 55/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9814
# Epoch 55: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 288ms/step - loss: 0.0610 - accuracy: 0.9814 - val_loss: 0.4736 - val_accuracy: 0.9267
# Epoch 56/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9843
# Epoch 56: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0445 - accuracy: 0.9843 - val_loss: 0.6080 - val_accuracy: 0.8833
# Epoch 57/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9746
# Epoch 57: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 291ms/step - loss: 0.0792 - accuracy: 0.9746 - val_loss: 0.7962 - val_accuracy: 0.8467
# Epoch 58/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9751
# Epoch 58: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0847 - accuracy: 0.9751 - val_loss: 0.4333 - val_accuracy: 0.9350
# Epoch 59/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9774
# Epoch 59: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0783 - accuracy: 0.9774 - val_loss: 0.6031 - val_accuracy: 0.8667
# Epoch 60/60
# 110/110 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9703
# Epoch 60: val_loss did not improve from 0.30685
# 110/110 [==============================] - 32s 289ms/step - loss: 0.0860 - accuracy: 0.9703 - val_loss: 0.4223 - val_accuracy: 0.9283

# %% [markdown]
# ##Biểu đồ và kết quả huấn luyện

# %%
# Vẽ biểu đồ huấn luyện
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, accuracy, label="Training accuracy")
plt.plot(epochs, val_accuracy, label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label="Training loss")
plt.plot(epochs, val_loss, label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# Mô hình học khá tốt, độ mất mát (loss) thấp và độ chính xác cũng cao

# %%
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test accuracy: {test_accuracy:.2f}")
# Out:
# 29/29 [==============================] - 2s 55ms/step - loss: 0.3983 - accuracy: 0.9211
# Test accuracy: 0.92

# %% [markdown]
# #Lưu model

# %%
# drive_path = '/content/gdrive/MyDrive/DeepLearning/Đồ án/HDF5'
# model_hdf5_path = drive_path + '/5Thing.hdf5'
# model.save(model_hdf5_path)
# print("Model đã được lưu vào:", model_hdf5_path)
# Out:
# Model đã được lưu vào: /content/gdrive/MyDrive/DeepLearning/Đồ án/5Thing.hdf5

# %% [markdown]
# #Show prediction

# %%
def show_predictions(dataset, model, class_names):
    count = 0
    fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(16, 8))
    for images, labels in dataset:
        # Chuyển đổi one-hot encoding thành nhãn
        true_labels = np.argmax(labels, axis=1)

        # Dự đoán trên tập dữ liệu
        predictions = model.predict(images)

        # Chuyển đổi one-hot encoding của dự đoán thành nhãn dự đoán
        predicted_labels = np.argmax(predictions, axis=1)

        # Lấy confidence
        confidence = np.max(predictions, axis=1)

        for i in range(images.shape[0]):  # Use images.shape[0] instead of images_np.shape[0]
            if count >= 10:
                break

            ax = axes[count // 5, count % 5]
            ax.imshow(images[i].numpy().astype(np.uint8))  # Convert EagerTensor to NumPy array

            if predicted_labels[i] == true_labels[i]:
                color = 'g'
            else:
                color = 'r'

            ax.set_title(f"Pred: {class_names[predicted_labels[i]]}-({class_names[true_labels[i]]})({confidence[i]:.2f})", color=color, size=10)
            ax.set(xticks=[], yticks=[])
            count += 1

        if count >= 10:
            break

    title = "Prediction results for images in a batch"
    fig.suptitle(title)
    plt.show()

# %%
show_predictions(test_dataset, model, CLASSES)
# Out:
# 1/1 [==============================] - 0s 82ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load model
loaded_model = load_model('/content/5Thing.hdf5')

# Function to evaluate and print classification report
def evaluate_model(model, dataset):
    true_labels = []
    predicted_labels = []

    for images, labels in dataset:
        true_labels.extend(np.argmax(labels, axis=1))  # Convert one-hot encoding to labels
        predictions = model.predict(images)
        predicted_labels.extend(np.argmax(predictions, axis=1))

    print("Classification Report:")
    print(classification_report(true_labels, predicted_labels))

    # Plot confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASSES, yticklabels=CLASSES)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Evaluate on the test dataset
evaluate_model(loaded_model, test_dataset)
# Out:
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 145ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       180
#            1       0.90      0.83      0.87       180
#            2       0.94      0.93      0.94       180
#            3       1.00      0.93      0.96       180
#            4       0.92      0.97      0.94       180
#
#     accuracy                           0.92       900
#    macro avg       0.92      0.92      0.92       900
# weighted avg       0.92      0.92      0.92       900
